# %%
import numpy as np
from wordcloud import WordCloud, STOPWORDS

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.collections import LineCollection
import seaborn as sns
import datetime
import re  
import string
from collections import Counter
import nltk  
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Εισάγουμε τις βιβλιοθήκες που θα χρειαστούμε
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import ast
import time

# %%
#Ορίζουμε τα headers για να νομίζει ο σέρβερ της ιστοσελίδας ότι πρόκειται για browser και όχι για εμάς!
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"}

# %%
#Παίρνουμε την σελίδα και την μετατρέπουμε σε ένα αντικείμενο beautiful soup (BS object).
response = requests.get("https://www.news247.gr/emvolio-koronoioy", headers=headers)
doc = BeautifulSoup(response.text)

# %%
#Πάμε στην ιστοσελίδα και ελέγχουμε τι ψάχνουμε να βρούμε, για παράδειγμα εδώ θέλουμε το h2 και συγκεκριμένα όλα τα a (δηλαδή τα a href)
#Τραβάμε τα links και τα σώζουμε σε μια λίστα
links = doc.select("h2 a")

# %%
links
# Out:
# [<a href="https://www.news247.gr/ygeia/koronoios-619-nea-kroysmata-simera-stin-ellada-6-nekroi-kai-177-diasolinomenoi.9284462.html" title="Κορονοϊός: 619 νέα κρούσματα σήμερα στην Ελλάδα - 6 νεκροί και 177 διασωληνωμένοι">
#                              Κορονοϊός: 619 νέα κρούσματα σήμερα στην Ελλάδα - 6 νεκροί και 177 διασωληνωμένοι</a>,
#  <a href="https://www.news247.gr/kosmos/kypros-kranioy-topos-tesseris-nekroi-terasties-katastrofes-apo-ti-megali-fotia.9284424.html" title="Κύπρος: Κρανίου τόπος - Τέσσερις νεκροί, τεράστιες καταστροφές από τη μεγάλη φωτιά">
#                              Κύπρος: Κρανίου τόπος - Τέσσερις νεκροί, τεράστιες καταστροφές από τη μεγάλη φωτιά</a>,
#  <a href="https://www.news247.gr/koinonia/kriti-thermoplixia-kai-exantlisi-ta-aitia-toy-thanatoy-tis-29chronis-violet.9284349.html" title="Κρήτη: Θερμοπληξία και εξάντληση τα αίτια του θανάτου της 29χρονης Βιολέτ">
# ...

# %%
print(len(links))
# Out:
# 43

# %%
links = set(links)
print(links)
# Out:
# {<a href="https://www.news247.gr/ygeia/emvolio-johnson-johnson-apotelesmatiko-kai-kata-tis-metallaxis-delta.9282054.html" title="Εμβόλιο Johnson &amp; Johnson: Αποτελεσματικό και κατά της μετάλλαξης Δέλτα">Εμβόλιο Johnson &amp; Johnson: Αποτελεσματικό και κατά της μετάλλαξης Δέλτα</a>, <a href="https://www.news247.gr/politiki/mitsotakis-me-ieronymo-praxi-agapis-pros-ton-plision-o-emvoliasmos-anorthodoxa-ayta-poy-akoygontai.9279978.html" title='Μητσοτάκης με Ιερώνυμο: "Πράξη αγάπης προς τον πλησίον ο εμβολιασμός - Ανορθόδοξα αυτά που ακούγονται"'>Μητσοτάκης με Ιερώνυμο: "Πράξη αγάπης προς τον πλησίον ο εμβολιασμός - Ανορθόδοξα αυτά που ακούγονται"</a>, <a href="https://www.news247.gr/kosmos/kypros-kranioy-topos-tesseris-nekroi-terasties-katastrofes-apo-ti-megali-fotia.9284424.html" title="Κύπρος: Κρανίου τόπος - Τέσσερις νεκροί, τεράστιες καταστροφές από τη μεγάλη φωτιά">
# ...

# %%
print(len(links))
# Out:
# 43

# %%
urls = [link['href'] for link in links]
urls
# Out:
# ['https://www.news247.gr/ygeia/emvolio-johnson-johnson-apotelesmatiko-kai-kata-tis-metallaxis-delta.9282054.html',
#  'https://www.news247.gr/politiki/mitsotakis-me-ieronymo-praxi-agapis-pros-ton-plision-o-emvoliasmos-anorthodoxa-ayta-poy-akoygontai.9279978.html',
#  'https://www.news247.gr/kosmos/kypros-kranioy-topos-tesseris-nekroi-terasties-katastrofes-apo-ti-megali-fotia.9284424.html',
#  'https://www.news247.gr/ygeia/ichiri-proeidopoiisi-eidikon-ergostasia-metallaxeon-oi-anemvoliastoi.9283819.html',
#  'https://www.news247.gr/ygeia/emvolio-koronoio-emvoliasmoi-akomi-kai-se-plaz.9280163.html',
#  'https://www.news247.gr/koinonia/emvoliasmenoi-kai-anemvoliastoi-mazi-stis-ekklisies-kamia-apantisi-apo-tin-kyvernisi.9282883.html',
#  'https://www.news247.gr/koinonia/oi-arches-ee-echoyn-apofanthei-nai-sto-pistopoiitiko-ochi-diakriseis-politon.9282381.html',
#  'https://www.news247.gr/koinonia/sarigiannis-cheiroteroi-oi-neoi-ypologismoi-2-000-kroysmata-ton-aygoysto.9284061.html',
# ...

# %%
print(len(urls))
# Out:
# 43

# %%
#Βλέπουμε ότι οι τίτλοι εμφανίζονται μέσα στο λινκ.
#Ας τους τραβήξουμε 
titles = [link.text for link in links]
titles
# Out:
# ['Εμβόλιο Johnson & Johnson: Αποτελεσματικό και κατά της μετάλλαξης Δέλτα',
#  'Μητσοτάκης με Ιερώνυμο: "Πράξη αγάπης προς τον πλησίον ο εμβολιασμός - Ανορθόδοξα αυτά που ακούγονται"',
#  '\n                            Κύπρος: Κρανίου τόπος - Τέσσερις νεκροί, τεράστιες καταστροφές από τη μεγάλη φωτιά',
#  'Ηχηρή προειδοποίηση ειδικών: "Εργοστάσια μεταλλάξεων οι ανεμβολίαστοι"',
#  'Αλαλούμ με τους εμβολιασμούς στην παραλία - Το εξήγγειλαν και το παίρνουν πίσω',
#  'Εμβολιασμένοι και ανεμβολίαστοι μαζί στις εκκλησίες; Καμία απάντηση από την κυβέρνηση',
#  'Οι αρχές της ΕΕ έχουν αποφανθεί: Ναι στο πιστοποιητικό, όχι στις διακρίσεις των πολιτών',
#  'Σαρηγιάννης: Χειρότεροι οι νέοι υπολογισμοί - 2.000 κρούσματα τον Αύγουστο ',
#  'Είναι ν΄απορείς…',
#  'Εστίαση - Ψυχαγωγία: Πώς θα γίνεται η είσοδος ανεμβολίαστων στους μικτούς χώρους',
#  'ΣΥΡΙΖΑ: Ο κ. Μητσοτάκης έχει αποφασίσει να διχάσει την ελληνική κοινωνία ',
# ...

# %%
#Φτιάχνουμε το function για το scraping που θα το χρησιμοποιήσουμε για να πάρουμε την λίστα με τα λινκς των άρθρων
from bs4 import BeautifulSoup
import requests
import time

headers = {'user-agent': 'my-app/0.0.1'}
PAUSE_TIME = 3.5

def get_text(urls):
    r = requests.get(urls, headers = headers)
    time.sleep(PAUSE_TIME)
    s = BeautifulSoup(r.content, 'html.parser')
    link = s.find("h2 a")
    
    return([s, link])

# %%
#Κάνω scraping κάθε σελίδα για να μαζέψω όλα τα links των άρθρων
scraped_links = []
titles = []
counter = 0
base_url = "https://www.news247.gr/emvolio-koronoioy?pages="
for i in range(0,100):
    url = base_url + str(i)
    #print(url)
    page = requests.get(url, headers = headers)
    s = BeautifulSoup(page.content, 'html.parser')
    #print(s)
    links = s.select("h2 a")
    links = set(links)
    
    url = [link['href'] for link in links]
    
    #title = [link.text for link in links]
    
    
    print(url)

    for l in url:
        link = l
        print(l)
        scraped_links.append(l)


    
    # Τυπώνει το νούμερο των links που είναι scraped
print(len(scraped_links)) 

scraped_links = (set(scraped_links))
# Out:
# ['https://www.news247.gr/ygeia/emvolio-johnson-johnson-apotelesmatiko-kai-kata-tis-metallaxis-delta.9282054.html', 'https://www.news247.gr/politiki/mitsotakis-me-ieronymo-praxi-agapis-pros-ton-plision-o-emvoliasmos-anorthodoxa-ayta-poy-akoygontai.9279978.html', 'https://www.news247.gr/kosmos/kypros-kranioy-topos-tesseris-nekroi-terasties-katastrofes-apo-ti-megali-fotia.9284424.html', 'https://www.news247.gr/ygeia/ichiri-proeidopoiisi-eidikon-ergostasia-metallaxeon-oi-anemvoliastoi.9283819.html', 'https://www.news247.gr/ygeia/emvolio-koronoio-emvoliasmoi-akomi-kai-se-plaz.9280163.html', 'https://www.news247.gr/koinonia/emvoliasmenoi-kai-anemvoliastoi-mazi-stis-ekklisies-kamia-apantisi-apo-tin-kyvernisi.9282883.html', 'https://www.news247.gr/koinonia/oi-arches-ee-echoyn-apofanthei-nai-sto-pistopoiitiko-ochi-diakriseis-politon.9282381.html', 'https://www.news247.gr/koinonia/sarigiannis-cheiroteroi-oi-neoi-ypologismoi-2-000-kroysmata-ton-aygoysto.9284061.html', 'https://www.news247.gr/gn
# ...

# %%
import pandas as pd
df = pd.DataFrame(scraped_links, columns= ['url'])
df
# Out:
#                                                     url
# 0     https://www.news247.gr/ygeia/nosokomeiakoi-gia...
# 1     https://www.news247.gr/koinonia/rodos-emvolias...
# 2     https://www.news247.gr/ygeia/koronoios-fovoi-g...
# 3     https://www.news247.gr/kosmos/koronoios-ta-emv...
# 4     https://www.news247.gr/kosmos/vrazilia-egkrith...
# ...                                                 ...
# 2083  https://www.news247.gr/koinonia/thessaloniki-t...
# 2084  https://www.news247.gr/ygeia/poy-tha-chreiaste...
# 2085  https://www.news247.gr/kosmos/koronoios-mia-no...
# 2086  https://www.news247.gr/koinonia/emvoliasmoi-an...
# 2087  https://www.news247.gr/koinonia/emvolio-korono...
#
# [2088 rows x 1 columns]

# %%
df.to_csv("urlnews_final.csv", index=False)

# %%
df = pd.read_csv('urlnews_final.csv')
df.head(4)
# Out:
#                                                  url
# 0  https://www.news247.gr/ygeia/nosokomeiakoi-gia...
# 1  https://www.news247.gr/koinonia/rodos-emvolias...
# 2  https://www.news247.gr/ygeia/koronoios-fovoi-g...
# 3  https://www.news247.gr/kosmos/koronoios-ta-emv...

# %%
urls = df['url'].tolist()
urls[0:5]
# Out:
# ['https://www.news247.gr/ygeia/nosokomeiakoi-giatroi-gia-emvoliasmoys-kyvernitikon-den-dinoyn-dekara-tsakisti-gia-tin-ygeia-mas.9096417.html',
#  'https://www.news247.gr/koinonia/rodos-emvoliastike-o-teleytaios-epizon-dodekanisios-ierolochitis.9126440.html',
#  'https://www.news247.gr/ygeia/koronoios-fovoi-gia-nea-metallaxi-apo-ton-sygchrotismo-emvoliasmenon-kai-mi.9116045.html',
#  'https://www.news247.gr/kosmos/koronoios-ta-emvolia-endechetai-na-min-synistontai-archika-gia-ta-paidia.9018903.html',
#  'https://www.news247.gr/kosmos/vrazilia-egkrithikan-dokimes-se-anthropoys-toy-ypopsifioy-emvolioy-tis-johsnon-johnson.7698325.html']

# %%
#Kάνουμε scrape την κάθε σελίδα που περιέχει ένα άρθρο

# %% [markdown]
# Πάιρνουμε ένα άρθρο για να βρούμε τα στοιχεία που θέλουμε

# %%
response = requests.get("https://www.news247.gr/koinonia/emvolio-koronoioy-pote-tha-egkrithei-gia-toys-anilikoys-me-poio-skeyasma-tha-emvoliastoyn.9283658.html", headers=headers)

doc = BeautifulSoup(response.text)

# %%
# Τίτλος
titles = doc.select("h1")[0].text
titles
# Out:
# '\r\n\t\t\t\t\tΕμβόλιο Κορονοϊού: Πότε θα εγκριθεί για τους ανήλικους - Με ποιο σκεύασμα θα εμβολιαστούν'

# %%
#Κώδικας για μας βοηθήσει να βρούμε την ημερομηνία
 <div class="article-body__byline noeditor">
                    <a style="font-size:13px;" href="/">news247</a>
                    <span class="article-body__date">
                       <time datetime="2021-07-03 15:32"> 03 Ιουλίου 2021&nbsp;15:32</time>
                    </span>
                </div>

# %%
#Ημερομηνία

date2 = doc.find('time')
datetime = date2['datetime']
datetime
#date = doc.select("time")[1].text.strip()
#date
# Out:
# '2021-07-03 15:32'

# %%
#Κώδικας για να βρούμε το article
<div class="article-body__storyContent ">
        <div class="article-body__body">	
            <p>Θέμα ημερών φαίνεται πως είναι η έγκριση <a href="https://www.news247.gr/emvolio-koronoioy" target="_self" rel="Follow">εμβολιασμών</a> των εφήβων από την Εθνική Επιτροπή Εμβολιασμών, σύμφωνα με όσα είπε <span>ο καθηγητής Παιδιατρικής του ΕΚΠΑ και μέλος της Επιτροπής Εμβολιασμών, Γιώργος Χρούσος.</span></p>
<!-- /4834629/news247.gr/ros_inline_A --> 
<style>
    .ros-inlineA_title::before { content: ""; width: 100%; height: 1px; background: #cfcfcf; display: block; top: 5px; position: relative; }
    .ros-inlineA_title { margin: auto; }
    .ros-inlineA_title .ad_label { width: 95px; font-family: Roboto Slab; font-size: 10px; font-weight: 400; line-height: 8px;color: #cfcfcf; position: relative; background: #fff; text-align: center; margin: 0 auto 5px; }
</style> 
<div id="advertisment" style="margin-top:20px; margin-bottom:20px;"> 
 <div class="ros-inlineA_title" style="display:none;"> 
  <div class="ad_label">
    ADVERTISING 
  </div> 
 </div> 
 <div id="ros-inlineA" style="margin-top:20px;border-bottom: 1px solid rgb(221, 221, 221); padding-bottom: 20px;" oau-code="/4834629/news247.gr/ros_inline_A" lazyloaded-by-ocm=""> 
  <script>
            googletag.cmd.push(function() { googletag.display('ros-inlineA'); });
        </script> 
 <div id="google_ads_iframe_/4834629/news247.gr/ros_inline_A_0__container__" style="border: 0pt none; margin: auto; text-align: center; width: 300px; height: 0px;"></div></div> 
</div> 
<p><span>Δεν αποκλείεται </span><span>ακόμη και την ερχόμενη Τρίτη, η Εθνική Επιτροπή Εμβολιασμών να να εγκρίνει τον εμβολιασμό εφήβων ηλικίας από 15-17 ετών, δίνοντας έτσι την εκκίνηση για τον εμβολιασμό των ανηλίκων.</span></p> 
<p>"<i>Σίγουρα στο εγγύς μέλλον, εντός του Ιουλίου, πιθανώς και την ερχόμενη Τρίτη, θα εγκριθούν οι εμβολιασμοί για παιδιά μεταξύ 15-17 ετών και αργότερα ίσως και για μικρότερες ηλικίες", </i>είπε ο κ. Χρούσος στον ΣΚΑΪ, συμπληρώνοντας ότι είναι καλό να εμβολιαστεί η εν λόγω ηλικιακή ομάδα, καθώς δεν διαφέρει πολύ από τους νέους 18-20 ετών, δεδομένου ότι μετακινούνται συχνά.</p> 
<p><span>Παράλληλα, ο κ. Χρούσος σημείωσε ότι θα δοθεί </span><span>προτεραιότητα </span><span>στους εφήβους με υποκείμενα νοσήματα αφήνοντας ανοιχτό το ενδεχόμενο η Επιτροπή να συστήσει και τον εμβολιασμό παιδιών ηλικίας 12-15 ετών που ανήκουν σε αυτή την κατηγορία.</span></p> 
<p><span>Όπως ξεκαθάρισε, οι γονείς δεν θα πρέπει να ανησυχούν, καθώς τα εμβόλια έχουν δοκιμαστεί στις ηλικίες 12-15 ετών, είναι ασφαλή και δεν παρουσιάζουν επιπλοκές: </span><span>«Τα χιλιάδες παιδιά που εμβολιάστηκαν στις ΗΠΑ είναι όλα καλά», τόνισε, χωρίς όμως να αποκλείει κάποια ανεπιθύμητη παρενέργεια, αν και αυτό όπως είπε συμβαίνει πολύ σπάνια.</span></p> 
<p>Τέλος, επισήμανε ότι το μόνο διαθέσιμο σκεύασμα κατά της Covid για τα παιδιά είναι εκείνο της Pfizer, καθώς είναι το μόνο που έχει δοκιμαστεί σε αυτές τις ηλικίες.</p> 
<p><i>Ακολουθήστε το <a href="https://news.google.com/publications/CAAiEPBbzilxLAOqHZhOPBpiQF8qFAgKIhDwW84pcSwDqh2YTjwaYkBf?oc=3&amp;ceid=GR:el">News247.gr στο Google News </a>και μάθετε πρώτοι όλες τις <a href="https://www.news247.gr/latest/">ειδήσεις</a></i></p></div>
    </div>

# %%
#Κείμενο άρθρου
body = doc.find(class_ ="article-body__body")
text = [p.text for p in body.find_all("p")]
text
# Out:
# ['Θέμα ημερών φαίνεται πως είναι η έγκριση εμβολιασμών των εφήβων από την Εθνική Επιτροπή Εμβολιασμών, σύμφωνα με όσα είπε ο καθηγητής Παιδιατρικής του ΕΚΠΑ και μέλος της Επιτροπής Εμβολιασμών, Γιώργος Χρούσος.',
#  'Δεν αποκλείεται ακόμη και την ερχόμενη Τρίτη, η Εθνική Επιτροπή Εμβολιασμών να να εγκρίνει τον εμβολιασμό εφήβων ηλικίας από 15-17 ετών, δίνοντας έτσι την εκκίνηση για τον εμβολιασμό των ανηλίκων.',
#  '"Σίγουρα στο εγγύς μέλλον, εντός του Ιουλίου, πιθανώς και την ερχόμενη Τρίτη, θα εγκριθούν οι εμβολιασμοί για παιδιά μεταξύ 15-17 ετών και αργότερα ίσως και για μικρότερες ηλικίες", είπε ο κ. Χρούσος στον ΣΚΑΪ, συμπληρώνοντας ότι είναι καλό να εμβολιαστεί η εν λόγω ηλικιακή ομάδα, καθώς δεν διαφέρει πολύ από τους νέους 18-20 ετών, δεδομένου ότι μετακινούνται συχνά.',
# ...

# %%
#Κώδικας κατηγορία άρθρου
<div class="article-head">
        <a title="Υγεία" href="/ygeia/" class="article-head__article-head-section-name">
                        ΥΓΕΙΑ</a>
            <div class="col-xs-12">
                <div class="code-widget ">
    <script>

# %%
#Κατηγροία άρθρου
category1 = doc.find(class_ ="article-head")
tex = [a.text for a in category1.find_all("a")] 
tex
# Out:
# ['\r\n                        ΚΟΙΝΩΝΙΑ']

# %% [markdown]
# -Βάζουμε όλα τα στοιχεία μαζί

# %%
from bs4 import BeautifulSoup
import os
import requests
from datetime import datetime
import ast
import time


list=[]
for i in urls[0:700]:  #βάζω συγκεκριμένο αριθμό για τεστ
    dic = {}
    #url = base_url + str(i)
    print(i)
    page = requests.get(i, headers = headers)
    soup = BeautifulSoup(page.content, 'html.parser')

    
    title = soup.select("h1")

    if (title):
        dic['title'] = soup.select("title")[0].text
    else:
        print("ARTICLE NO: ", link, " HAS NO TITLE")
        dic['title'] = "NO TITLE"
    
        
    date2 = soup.find('time')
    if (date2):
        dic['date'] = date2['datetime']
    else:
        print("ARTICLE NO: ", link, " HAS NO date")
        dic['date'] = "NO date"       
        
    
    article = soup.find(class_ ="article-body__body")
    if (article):
        dic['body'] = [p.text for p in article.find_all("p")] 
    else:
        print("ARTICLE NO: ", link, " HAS NO body")
        dic['body'] = "NO body"  


    category1 = soup.find(class_ ="article-head")
    if (category1):
        dic['category'] = [a.text for a in category1.find_all("a")]  
    else:
        print("Category NO: ", link, " HAS NO category")
        dic['category'] = "NO category" 

    
    auth = soup.find(class_ ="article-body__author-name")
    if (auth):
        dic['author'] =  auth.text 
    else:
        print("Author NO: ", link, " HAS NO author")
        dic['author'] = "NO author" 
    #article =  soup.select("#modal-ready")[0].text
    
    #article_text = [a.text for a in article]
    #dic['body'] = article
    
    dic['url'] = i

    
    list.append(dic)
    #print(dic)
    
    time.sleep(0.5) #ορίζω πόση ώρα θα περιμένει μέχρι να ξαναχτυπήσει τον σέρβερ για να πάρει το επόμενο
# Out:
# https://www.news247.gr/ygeia/nosokomeiakoi-giatroi-gia-emvoliasmoys-kyvernitikon-den-dinoyn-dekara-tsakisti-gia-tin-ygeia-mas.9096417.html
# Author NO:  https://www.news247.gr/ygeia/koronoios-619-nea-kroysmata-simera-stin-ellada-6-nekroi-kai-177-diasolinomenoi.9284462.html  HAS NO author
# https://www.news247.gr/koinonia/rodos-emvoliastike-o-teleytaios-epizon-dodekanisios-ierolochitis.9126440.html
# Author NO:  https://www.news247.gr/ygeia/koronoios-619-nea-kroysmata-simera-stin-ellada-6-nekroi-kai-177-diasolinomenoi.9284462.html  HAS NO author
# https://www.news247.gr/ygeia/koronoios-fovoi-gia-nea-metallaxi-apo-ton-sygchrotismo-emvoliasmenon-kai-mi.9116045.html
# https://www.news247.gr/kosmos/koronoios-ta-emvolia-endechetai-na-min-synistontai-archika-gia-ta-paidia.9018903.html
# Author NO:  https://www.news247.gr/ygeia/koronoios-619-nea-kroysmata-simera-stin-ellada-6-nekroi-kai-177-diasolinomenoi.9284462.html  HAS NO author
# ...

# %%
df2 = pd.DataFrame(list)
df2
# Out:
#                                                  title  ...                                                url
# 0    Νοσοκομειακοί γιατροί για εμβολιασμούς κυβερνη...  ...  https://www.news247.gr/ygeia/nosokomeiakoi-gia...
# 1    Ρόδος: Εμβολιάστηκε ο τελευταίος επιζών Δωδεκα...  ...  https://www.news247.gr/koinonia/rodos-emvolias...
# 2    Κορονοϊός: Φόβοι για νέα μετάλλαξη από τον συγ...  ...  https://www.news247.gr/ygeia/koronoios-fovoi-g...
# 3    Κορονοϊός: Τα εμβόλια ενδέχεται να μην συνιστώ...  ...  https://www.news247.gr/kosmos/koronoios-ta-emv...
# 4    Βραζιλία: Εγκρίθηκαν δοκιμές σε ανθρώπους του ...  ...  https://www.news247.gr/kosmos/vrazilia-egkrith...
# ..                                                 ...  ...                                                ...
# 695  Κορονοϊός: Το φάρμακο ρεμδεσιβίρη αποδείχθηκε ...  ...  https://www.news247.gr/kosmos/koronoios-to-far...
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df2.to_csv("/content/gdrive/My Drive/Colab Notebooks/news247_final.tsv", sep='\t')

# %%
df2
# Out:
#                                                  title  ...                                                url
# 0    Νοσοκομειακοί γιατροί για εμβολιασμούς κυβερνη...  ...  https://www.news247.gr/ygeia/nosokomeiakoi-gia...
# 1    Ρόδος: Εμβολιάστηκε ο τελευταίος επιζών Δωδεκα...  ...  https://www.news247.gr/koinonia/rodos-emvolias...
# 2    Κορονοϊός: Φόβοι για νέα μετάλλαξη από τον συγ...  ...  https://www.news247.gr/ygeia/koronoios-fovoi-g...
# 3    Κορονοϊός: Τα εμβόλια ενδέχεται να μην συνιστώ...  ...  https://www.news247.gr/kosmos/koronoios-ta-emv...
# 4    Βραζιλία: Εγκρίθηκαν δοκιμές σε ανθρώπους του ...  ...  https://www.news247.gr/kosmos/vrazilia-egkrith...
# ..                                                 ...  ...                                                ...
# 695  Κορονοϊός: Το φάρμακο ρεμδεσιβίρη αποδείχθηκε ...  ...  https://www.news247.gr/kosmos/koronoios-to-far...
# ...

# %%
vaccine =pd.read_csv("/content/drive/MyDrive/Colab Notebooks/news247_final.tsv", sep='\t')
vaccine
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...  https://www.news247.gr/ygeia/nosokomeiakoi-gia...
# 1             1  ...  https://www.news247.gr/koinonia/rodos-emvolias...
# 2             2  ...  https://www.news247.gr/ygeia/koronoios-fovoi-g...
# 3             3  ...  https://www.news247.gr/kosmos/koronoios-ta-emv...
# 4             4  ...  https://www.news247.gr/kosmos/vrazilia-egkrith...
# ..          ...  ...                                                ...
# 695         695  ...  https://www.news247.gr/kosmos/koronoios-to-far...
# 696         696  ...  https://www.news247.gr/koinonia/i-apantisi-toy...
# 697         697  ...  https://www.news247.gr/kosmos/kina-emvoliasmen...
# 698         698  ...  https://www.news247.gr/ygeia/emvolio-coronavac...
# 699         699  ...  https://www.news247.gr/kosmos/rosia-etaireia-e...
#
# [700 rows x 7 columns]

# %%
vaccine.shape
# Out:
# (700, 7)
